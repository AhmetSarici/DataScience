# %% [markdown]
# # Veri Görselleştirme

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#veri= pd.read_csv("temizlenmis_olumpiyat.csv")
veri= pd.read_csv("C://Users//ahmet//OneDrive//Belgeler//VS-PY//temizlenmis_olimpiyat.csv")
veri.head()
# Out:
#                        isim cinsiyet   yas     boy   kilo           takim  \
# 0      Edgar Lindenau Aabye        M  34.0  182.48  95.62  Denmark/Sweden
# 1      Arvo Ossian Aaltonen        M  30.0  182.01  76.69         Finland
# 2      Arvo Ossian Aaltonen        M  30.0  177.00  75.00         Finland
# 3  Juhamatti Tapio Aaltonen        M  28.0  184.00  85.00         Finland
# 4   Paavo Johannes Aaltonen        M  28.0  175.00  64.00         Finland
#
#    uok   yil   sezon      sehir        spor  \
# 0  DEN  1900  Summer      Paris  Tug-Of-War
# 1  FIN  1920  Summer  Antwerpen    Swimming
# 2  FIN  1920  Summer  Antwerpen    Swimming
# 3  FIN  2014  Winter      Sochi  Ice Hockey
# 4  FIN  1948  Summer     London  Gymnastics
#
#                                  etkinlik madalya
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %% [markdown]
# ## Saçılım Grafiği
# İki farklı değişken arasındaki ilişki

# %%
def sacilim():
  sns.scatterplot(x="boy",y="kilo",data=veri)
  plt.title("Boy ve Ağırlık İlişkisi")
  plt.show()
sacilim()

# %%
sns.set_style("darkgrid")
sacilim()

# %% [markdown]
# Saçılım Grafiği - Kategorik

# %%
sns.scatterplot(x="boy",y="kilo",hue="madalya",data=veri)
plt.title("Madalya Göre Boy ve Ağırlık Dağılımı")
plt.show()

# %%
sns.scatterplot(x="boy",y="kilo",hue="cinsiyet", style="madalya",data=veri)
plt.title("Madalya Göre Boy ve Ağırlık Dağılımı")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x="boy",y="kilo",hue="cinsiyet",style="madalya",size="yas",sizes=(15,200),data=veri)
plt.title("Madalya Göre Boy ve Ağırlık Dağılımı")
plt.xlabel("Sporcuların Boyu")
plt.ylabel("Sporcuların Ağırlığı")
plt.show()

# %% [markdown]
# Saçılım Grafiği - Doğrusal Regresyon

# %%
sns.regplot(x="boy",
            y="kilo",
            data=veri,
            marker="+",
            scatter_kws={"alpha":0.2})
plt.title("Boy ve Ağırlık Dağılımı")
plt.show()

# %% [markdown]
# Renk Paleti

# %%
sns.scatterplot(x="boy",
                y="kilo",
                hue="madalya",
                data=veri,
                palette="Set1")
plt.title("Madalyaya Göre Boy ve AĞırlık Dağılımı")
plt.show()

# %%
sns.scatterplot(x="boy",
                y="kilo",
                hue="madalya",
                data=veri,
                palette="rocket")
plt.title("Madalyaya Göre Boy ve AĞırlık Dağılımı")
plt.show()

# %% [markdown]
# Çizgi Grafiği

# %%
sns.lineplot(x="boy",
             y="kilo",
             data=veri)
plt.title("Boy ve Kilo")
plt.show()

# %% [markdown]
# Çizgi Grafiği - Kategorik

# %%
sns.lineplot(x="boy",
             y="kilo",
             hue="cinsiyet",
             data=veri)
plt.title("Cinsiyete Göre Boy ve Kilo")
plt.show()

# %%
sns.lineplot(x="boy",
             y="kilo",
             hue="madalya",
             data=veri)
plt.title("Madalyaya Göre Boy ve Kilo")
plt.show()

# %%
sns.lineplot(x="boy",
             y="kilo",
             hue="sezon",
             data=veri)
plt.title("Sezona Göre Boy ve Kilo")
plt.show()

# %% [markdown]
# ## Histogram

# %%
sns.displot(veri,
            x="kilo")
plt.ylabel("Frekans")
plt.title("Ağırlık Histogramı")
plt.show()

# %% [markdown]
# Histogram - Kategorik

# %%
sns.displot(veri,
            x="kilo",
            hue="cinsiyet")
plt.ylabel("Frekans")
plt.title("Cinsiyete Göre Ayrıştırılmış Ağırlık Histogramı")
plt.show()

# %%
sns.displot(veri,
            x="kilo",
            col="cinsiyet",
            multiple="dodge")
plt.show()

# %% [markdown]
# İki Boyutlu Histogram

# %%
sns.displot(veri,
            x="kilo",
            y="boy",
            kind="kde")
plt.xlabel("Ağırlık")
plt.ylabel("Boy")
plt.title("Ağırlık-Boy Histogramı")
plt.show()

# %%
sns.displot(veri,
            x="kilo",
            y="boy",
            hue="cinsiyet",
            kind="kde")
plt.xlabel("Ağırlık")
plt.ylabel("Boy")
plt.title("Cinsiyete Göre Ayrıştırılmış Ağırlık-Boy Histogramı")
plt.show()

# %%
sns.kdeplot(data=veri,
            x="kilo",
            y="boy",
            hue="cinsiyet",
            fill=True)
plt.xlabel("Ağırlık")
plt.ylabel("Boy")
plt.title("Ağırlık-Boy Histogramı")
plt.show()

# %% [markdown]
# ## Çubuk Grafiği
#
# * BarPlot (Kategorik Veriler)

# %%
sns.barplot(x="madalya",
            y="boy",
            data=veri)
plt.title("Madalyalara Göre Boy Grafikleri")
plt.show()

# %%
sns.barplot(x="madalya",
            y="boy",
            hue="cinsiyet",
            data=veri)
plt.title("Madalyalara Göre Boy Grafikleri")
plt.show()

# %%
sns.catplot(x="madalya",
            y="yas",
            hue="cinsiyet",
            col="sezon",
            data=veri,
            kind="bar",
            height=4,
            aspect=0.7)
plt.show()

# %% [markdown]
# ## Kutu Grafiği

# %%
sns.boxplot(x="sezon",
            y="boy",
            data=veri)
plt.show()

# %%
sns.boxplot(x="sezon",
            y="boy",
            hue="cinsiyet",
            palette="rocket",
            data=veri)
plt.show()

# %%
veri_gecici=veri.loc[:,["yas","kilo","boy"]]
sns.boxplot(data=veri_gecici,
            orient="h",
            palette="rocket")
plt.show()

# %%
sns.catplot(x="sezon",
            y="boy",
            hue="cinsiyet",
            col="madalya",
            data=veri,
            kind="box",
            height=4,
            aspect=0.7)
plt.show()

# %% [markdown]
# ## Isı Haritası (Sayısal)

# %%
from seaborn import palettes
sns.heatmap(veri.corr(),
            annot=True,
            linewidth=0.5,
            linecolor="black",
            fmt=".1f")
plt.show()

# %% [markdown]
# Keman Grafiği

# %%
sns.violinplot(x="sezon",
               y="boy",
               data=veri)
plt.show()

# %%
sns.violinplot(x="sezon",
               y="boy",
               hue="cinsiyet",
               palette="rocket",
               data=veri)
plt.show()

# %%
sns.violinplot(x="sezon",
               y="boy",
               hue="cinsiyet",
               palette="rocket",
               split=True,
               data=veri)
plt.show()

# %%
sns.catplot(x="sezon",
            y="boy",
            hue="cinsiyet",
            col="madalya",
            data=veri,
            kind="violin",
           # split=True,
            height=4,
            aspect=0.7)
plt.show()

# %% [markdown]
# Ortaklık Grafiği (Farklı Özellikler)

# %%
sns.jointplot(data=veri,
              x="kilo",
              y="boy",
              hue="sezon",
              kind="kde")
plt.show()

# %%
g=sns.JointGrid(data=veri,
              x="kilo",
              y="boy")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)
plt.show()

# %% [markdown]
# ## Çift/Eş Grafiği

# %%
sns.pairplot(veri)
plt.show()

# %%
g=sns.PairGrid(veri)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot,fill=True)
g.map_diag(sns.histplot,kde=True)

# %% [markdown]
# ## Countplot (Sayma Grafiği)

# %%
sns.countplot(x="sehir",data=veri)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Plotly Kütüphanesi

# %% [markdown]
# **Dünya Üniversite Sıralaması Veri Seti**
#
# * world_renk    : dünya sıralaması
# * universty_name: üniversite ismi
# * country       : üni. bulunduğu ülke
# * teaching      : öğretim puanı
# * international : uluslar arası öğrenci/çalışan açısından üni. puanı
# * research      : araştırma puanı
# * citations     : alıntı puanı
# * income        : gelir puanı
# * total_score   : toplam puan
# * num_student   : toplam puan
# * student_staff_ratio   : öğrenci/çalışan oranı
# * international_student : uluslararası öğrenci oranı
# * female_male_ratio : kadın/erkek öğrenci oranı
# * year              : sıralamanın yapıldığı yıl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


import warnings
warnings.filterwarnings("ignore")

from plotly.offline import init_notebook_mode,iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.io as pio
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
veri= pd.read_csv("C://Users//ahmet//OneDrive//Belgeler//VS-PY//Veri Setleri3//universite_siralamasi_20220204.csv")
veri.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
veri.columns
# Out:
# Index(['world_rank', 'university_name', 'country', 'teaching', 'international',
#        'research', 'citations', 'income', 'total_score', 'num_students',
#        'student_staff_ratio', 'international_students', 'female_male_ratio',
#        'year'],
#       dtype='object')

# %%
veri.rename(columns={'world_rank'     :"dunya_siralama",
                     'university_name':"uni_isim",
                     'country'        :"ulke",
                     'teaching'       :"ogretim",
                     'international'  :"uluslararasi",
                     'research'       :"arastirma",
                     'citations'      :"alinti",
                     'income'         :"gelir",
                     'total_score'    :"toplam_puan",
                     'num_students'   :"ogrenci_sayisi",
                     'student_staff_ratio':"ogrenci_calisan_orani",
                     'international_students':"uluslararasi_ogrenci",
                     'female_male_ratio':"kadin_erkek_orani",
                     'year'           :"yil"},
                    inplace=True)
veri.head(3)
# Out:
#   dunya_siralama                               uni_isim  \
# 0              1                     Harvard University
# 1              2     California Institute of Technology
# 2              3  Massachusetts Institute of Technology
#
#                        ulke  ogretim uluslararasi  arastirma  alinti gelir  \
# 0  United States of America     99.7         72.4       98.7    98.8  34.5
# 1  United States of America     97.7         54.6       98.0    99.9  83.7
# 2  United States of America     97.8         82.3       91.4    99.9  87.5
#
#   toplam_puan ogrenci_sayisi  ogrenci_calisan_orani uluslararasi_ogrenci  \
# 0        96.1         20,152                    8.9                  25%
# 1        96.0          2,243                    6.9                  27%
# 2        95.6         11,074                    9.0                  33%
#
#   kadin_erkek_orani   yil
# 0               NaN  2011
# 1           33 : 67  2011
# 2           37 : 63  2011

# %% [markdown]
# Çizgi Grafiği

# %%
df=veri.iloc[:100,:] #ilk 100 üniversite
df.head(3)
# Out:
#   dunya_siralama                               uni_isim  \
# 0              1                     Harvard University
# 1              2     California Institute of Technology
# 2              3  Massachusetts Institute of Technology
#
#                        ulke  ogretim uluslararasi  arastirma  alinti gelir  \
# 0  United States of America     99.7         72.4       98.7    98.8  34.5
# 1  United States of America     97.7         54.6       98.0    99.9  83.7
# 2  United States of America     97.8         82.3       91.4    99.9  87.5
#
#   toplam_puan ogrenci_sayisi  ogrenci_calisan_orani uluslararasi_ogrenci  \
# 0        96.1         20,152                    8.9                  25%
# 1        96.0          2,243                    6.9                  27%
# 2        95.6         11,074                    9.0                  33%
#
#   kadin_erkek_orani   yil
# 0               NaN  2011
# 1           33 : 67  2011
# 2           37 : 63  2011

# %%
from IPython.display import HTML
import plotly.express as px

# %%
#plotly stilleri
pio.templates.default="simple_white"

# %%
cizgi1=go.Scatter(x=df.dunya_siralama,
                  y=df.alinti,
                  mode="lines+markers",
                  name="Alıntı",
                  marker=dict(color="rgba(78,78,250,0.85)"),
                  text=df.uni_isim)
cizgi2=go.Scatter(x=df.dunya_siralama,
                  y=df.ogretim,
                  mode="lines+markers",
                  name="Eğitim-Öğretim Faaliyetleri",
                  marker=dict(color="rgba(202,43,15,0.85)"),
                  text=df.uni_isim)
veri=[cizgi1,cizgi2]
yerlesim=dict(title="Dünya Sıralamasında İlk 100 Üniversitenin Atıf ve Eğitim-Öğretim Puanları",
              xaxis=dict(title="Dünya Sıralaması", ticklen=5, zeroline=False))
fig=dict(data=veri, layout=yerlesim)
plot(fig,filename="1_çizgi-alıntı ve öğretim puanları.html")
# Out:
# '1_çizgi-alıntı ve öğretim puanları.html'

# %% [markdown]
# Dairesel Grafik

# %%
#configure_plotly_browser_state()

#init_notebook_mode(connected=False)

veri2011=df[df.yil==2011].iloc[:8,:]
dilim1=veri2011.ogrenci_sayisi
dilim1_liste=[float(each.replace(",",".")) for each in veri2011.ogrenci_sayisi]
etiketler =veri2011.uni_isim

cizgi=go.Pie(labels=etiketler,
             values =dilim1_liste,
             hoverinfo="label+value+percent",
             textinfo="value+percent",
             textfont=dict(size=8),
             rotation=180,
             hole=0.3,
             marker=dict(line=dict(color="#000000",width=1)))
veri_=[cizgi]
yerlesim=dict(title="2011 Yılı İlk 8 Üniversitenin Öğrenci Sayısı ve Oranları",
              legend=dict(orientation="h"))
fig=dict(data=veri_, layout=yerlesim) 
plot(fig,filename="3_diresel-öğrenci sayısı.html")
# Out:
# '3_diresel-öğrenci sayısı.html'

# %% [markdown]
# Kabarcık Grafiği

# %%
"""
veri2011 =df[df.yil==2011].iloc[:20,:]
ogrenci_sayisi=[float(each.replace(",",".")) for each in veri2011.ogrenci_sayisi]
uluslararasi_renk=[float(each for each in veri2011.uluslararasi)]

data=[{"y":veri2011.ogretim,
       "x":veri2011.dunya_siralama,
       "mode":"markers",
       "marker":{"color":uluslararasi_renk,
                  "size":ogrenci_sayisi,
                  "showscale":True},
        "text":veri2011.uni_isim}]
plot(data, filename="4_kabarcık-öğrenci sayısı.html")        
"""
# Out:
# '\nveri2011 =df[df.yil==2011].iloc[:20,:]\nogrenci_sayisi=[float(each.replace(",",".")) for each in veri2011.ogrenci_sayisi]\nuluslararasi_renk=[float(each for each in veri2011.uluslararasi)]\n\ndata=[{"y":veri2011.ogretim,\n       "x":veri2011.dunya_siralama,\n       "mode":"markers",\n       "marker":{"color":uluslararasi_renk,\n                  "size":ogrenci_sayisi,\n                  "showscale":True},\n        "text":veri2011.uni_isim}]\nplot(data, filename="4_kabarcık-öğrenci sayısı.html")        \n'
